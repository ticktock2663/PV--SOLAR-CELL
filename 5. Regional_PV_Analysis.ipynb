# %% [markdown]
# # 5. Regional_PV_Analysis

# %% [markdown]
# 지역별 태양광 발전소 설비용량 분석

# %%
# 임포트
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 폰트 설정
plt.rc('font', family='Malgun Gothic')
# '-'(마이너스) 기호 깨짐 예방
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 1.데이터 읽기

# %%
df = pd.read_csv('./datasets/한국남부발전(주)_태양광발전기 사양정보_20220630.csv',encoding='cp949')
df
# Out:
#                      발전소명                                            발전소 주소지  \
# 0                남제주소내태양광                        제주도 서귀포시 안덕면 화순해안로 106번길 55
# 1             무릉리 태양광(제주)                      제주도 서귀포시 대정읍 무릉리 1193-3 외 3필지
# 2        부산 수처리 건물 태양광발전소                         부산광역시 사하구 감천항로 7(감천동) 수처리실
# 3   부산발전본부 1,400kW 태양광발전소                              부산광역시 사하구 감천항로 7(감천동)
# 4            부산복합 2단계 태양광                              부산광역시 사하구 감천항로 7(감천동)
# 5        부산복합 자재창고 태양광발전소                              부산광역시 사하구 감천항로 7(감천동)
# 6                 부산복합태양광                                   부산광역시 사하구 감천항로 7
# 7                 부산신항태양광                                 부산광역시 강서구 성북동 1490
# 8              부산역 선상 주차장                              부산광역시 동구 초량3동 1187-1
# 9           이천D(백사면B) 태양광                              경기도 이천시 백사면 도립리 141-1
# 10             삼척 소내태양광#4                                강원도 삼척시 원덕읍 삼척로 734
# 11               삼척사택 태양광                     강원도 삼척시 원덕읍 삼척로 581-7 삼척그린파워사택
# 12            삼척소내 태양광# 3                                강원도 삼척시 원덕읍 삼척로 734
# 13             삼척소내태양광 #2                                강원도 삼척시 원덕읍 삼척로 734
# 14              삼척소내태양광#1                                강원도 삼척시 원덕읍 삼척로 734
# 15            송당리 태양광(제주)                               제주도 제주시 구좌읍 송당리 2455
# 16       신인천 1,2단계주차장 태양광                              인천광역시 서구 장도로 57 (청라동)
# 17    신인천 법사면 전망대 태양광 발전소                              인천광역시 서구 장도로 57 (청라동)
# 18           신인천 북측부지 태양광                              인천광역시 서구 장도로 57 (청라동)
# 19           신인천 본관옥상 태양광                              인천광역시 서구 장도로 57 (청라동)
# 20         신인천 소내 태양광 발전소                              인천광역시 서구 장도로 57 (청라동)
# 21        신인천 주차장 태양광 발전소                              인천광역시 서구 장도로 57 (청라동)
# 22          신인천 해수취수구 태양광                              인천광역시 서구 장도로 57 (청라동)
# 23            신풍리 태양광(제주)                              제주도 서귀포시 성산읍 신풍리 1522
# 24         안동발전본부 2단계 태양광                            경상북도 안동시 풍산읍 산업단지 1길 38
# 25          안동발전본부 태양광발전소                            경상북도 안동시 풍산읍 산업단지 1길 38
# 26                영월복합태양광                                강원도 영월군 영월읍 중앙로 411
# 27             영월철도부지 태양광                    강원도 영월군 영월읍 중앙로 411 정양리 일원(585)
# 28             위미2리 제2태양광                      제주도 제주특별자치도 서귀포시 남원읍 위미리 3696
# 29             인천수산정수장태양광                                인천광역시 남동구 수산동 294-4
# 30             제주 용수리 태양광                            제주도 제주시 한경면 용수리 457 외 2
# 31             하동공설운동장태양광                            경상남도 하동군 적량면 고절리 1209-1
# 32              하동군보건소태양광                             경상남도 하동군 하동읍 읍내리 149-1
# 33               하동변전소태양광                               경상남도 하동군 적량면 동산리 867
# 34               하동정수장태양광                               경상남도 하동군 하동읍 두곡리 543
# 35             하동하수처리장태양광                               경상남도 하동군 하동읍 신기리 2-2
# 36             하동화력태양광 #1                               경상남도 하동군 금성면 가덕리 310
# 37             하동화력태양광 #2                               경상남도 하동군 금성면 가덕리 310
# 38             하동화력태양광 #3                               경상남도 하동군 금성면 가덕리 310
# 39             하동화력태양광 #4  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 40             하동화력태양광 #5  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 41             하동화력태양광 #6                          경상남도 하동군 금성면 가덕리 1321,309
# 42         화촌주민참여형솔라팜 태양광                      경상남도 하동군 양보면 지례리 183-5 외 10필지
# 43               행원소수력태양광                              제주도 제주시 구좌읍 행원리 571-2
# 44                감우리 태양광                         충청북도 충북 음성군 음성읍 감우리 23, 24
#
#                                                  설치용량  \
# 0              196kW 모듈 :250W x 784 인버터 : 100kW x 2EA
# 1         809.2kW 모듈 : 425W  x 1904 인버터 : 100kW x 8EA
# 2           110.5kW 모듈 : 340Wⅹ325 인버터 : 100kW, 10.5kW
# 3         1,400.475kW 모듈 : 355Wⅹ3,945 인버터 : 500kWⅹ3EA
# 4        501.84kW 모듈 : 340W x 1,476 인버터 : 600kW x 1EA
# 5               187kW 모듈 : 300Wⅹ624 인버터 : 100kW x 2EA
# 6   390kW 모듈 :170W x 1,155 인버터 : 100kW x 3EA, 50kW...
# 7   115kW 모듈 :144Wp x 272, 100Wp x 384, 215Wp x 17...
# 8           834kW 모듈 : 400W x 2086, 인버터 : 500kW x 2EA
# 9           995kW 모듈 : 440W x 2272, 인버터 : 500kW X 2EA
# 10       2,599.2kW 모듈 : 380Wⅹ6,840 인버터 : 1250kW x 2EA
# 11  241kW 모듈 : 250ⅹ964 인버터 : 36kWⅹ2, 41kWⅹ1, 46kWⅹ...
# 12  2,002.32kW 모듈 : 360Wⅹ5,562 인버터 : 500kWⅹ1EA, 15...
# 13           990.45kW모듈 : 355Wⅹ2,790 인버터 : 500kWⅹ2EA
# 14              999kW 모듈 : 360Wⅹ2,775 인버터 : 500kWⅹ2EA
# 15      996.93kW 모듈 : 330W ⅹ 3,021 인버터 : 105kW ⅹ 10EA
# 16          296.1kW 모듈 : 450W x 658 인버터 : 100kW x 3EA
# 17         1,742kW 모듈 :475W x 3,668 인버터 : 250kW x 7EA
# 18          302.4kW 모듈 : 450W x 672 인버터 : 100kW x 3EA
# 19           63.0kW 모듈 : 450W x 140 인버터 : 100kW x 1EA
# 20            200kW 모듈 : 250W x 800 인버터 : 210kW x 1EA
# 21  605.55kW 모듈 : 390W X1,545 인버터 : 100kW x 6EA, 3...
# 22        907.2kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 23       990.72kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 24          284.7kW 모듈 : 365W x 780 인버터 : 100kW x 3EA
# 25                  97.92kW모듈 : 340Wⅹ288 인버터 : 99.4kW
# 26  76kW 모듈 :175W x 432 인버터 : 30.21kVA x 2EA, 20kV...
# 27          1,190.7kW 모듈 : 350Wⅹ3,402 인버터 : 600kWⅹ2EA
# 28       994.84kW 모듈 : 340W x 2,926 인버터 : 500kW x 2EA
# 29           998kW 모듈 :230W x 4,284 인버터 : 250kW x 4EA
# 30       888.93kW 모듈 : 415W x 2,142 인버터 : 105kW x 9EA
# 31  369.85kW 모듈 :250W x 980, 144W x 867  인버터 : 250...
# 32               40kW 모듈 :250W x 220 인버터 : 40kW x 1EA
# 33             48.3kW 모듈 :230W x 210 인버터 : 50kW x 1EA
# 34           93.02kW 모듈 :144W x 646 인버터 : 100kW x 1EA
# 35               55kW 모듈 :250W x 160 인버터 : 55kW x 1EA
# 36         998.4kW 모듈 :160W x 6,256 인버터 : 250kW x 5EA
# 37  1900.8kW 모듈 :100/144/160/230W x 11,196 인버터 : 1...
# 38         600.6kW 모듈 :220W x 2,730 인버터 : 100kW x 7EA
# 39            997.56kW모듈 : 340Wⅹ2,934 인버터 : 500kWⅹ2EA
# 40        997.56W 모듈 : 340W x 2,934 인버터 : 500kW x 2EA
# 41       998.325kW 모듈 : 435W x 2295 인버터 : 500kW x 2EA
# 42        999.6kW 모듈 : 420W x 2380 인버터 : 100kW x 10EA
# 43                 6kW 모듈 :233W x 25 인버터 : 10kW x 1EA
# 44        554.4kW 모듈 : 440W x 1,260 인버터 : 630kW x 1EA
#
#                                설치각
# 0                        설치각 : 30˚
# 1                        설치각 : 20˚
# 2              설치각 : 25˚ 입사각 : 23˚
# 3                        설치각 : 25˚
# 4                        설치각 : 25˚
# 5                        설치각 : 27˚
# 6                    설치각 : 21˚~45˚
# 7                        설치각 : 17˚
# 8                     설치각 : 3˚~23˚
# 9                        설치각 : 25˚
# 10                       설치각 : 25˚
# 11                       사택 지붕에 설치
# 12                       설치각 : 25˚
# 13                       설치각 : 25˚
# 14  설치각 : 25˚(지면경사 : 0˚) 입사각 : 23˚
# 15                       설치각 : 24˚
# 16                       설치각 : 15˚
# 17                       설치각 : 20˚
# 18                       설치각 : 18˚
# 19                       설치각 : 25˚
# 20                     설치각 : 8~45˚
# 21              설치각 : 25˚, 10˚~20˚
# 22                       설치각 : 23˚
# 23                       설치각 : 24˚
# 24                       설치각 : 21˚
# 25                       설치각 : 25˚
# 26                       설치각 : 26˚
# 27  설치각 : 30˚(지면경사 : 0˚) 입사각 : 25˚
# 28                       설치각 : 25˚
# 29                       설치각 : 23˚
# 30                       설치각 : 18˚
# 31                       설치각 : 30˚
# 32                       설치각 : 30˚
# 33                       설치각 : 30˚
# 34                          지붕에 설치
# 35                       설치각 : 30˚
# 36                       설치각 : 32˚
# 37                       설치각 : 32˚
# 38                       설치각 : 32˚
# 39             설치각 : 30˚ 입사각 : 23˚
# 40                       설치각 : 30˚
# 41                       설치각 : 22˚
# 42                       설치각 : 20˚
# 43                       설치각 : 30˚
# 44                       설치각 : 20˚

# %% [markdown]
# ## 2. 데이터 전처리

# %% [markdown]
# #### 1) 설비용량 추출

# %%
df['설치용량'].head(4)
# Out:
# 0         196kW 모듈 :250W x 784 인버터 : 100kW x 2EA
# 1    809.2kW 모듈 : 425W  x 1904 인버터 : 100kW x 8EA
# 2      110.5kW 모듈 : 340Wⅹ325 인버터 : 100kW, 10.5kW
# 3    1,400.475kW 모듈 : 355Wⅹ3,945 인버터 : 500kWⅹ3EA
# Name: 설치용량, dtype: object

# %% [markdown]
# #### 방법 1)

# %%
# 숫자값 데이터 추출
# 숫자로 인식
# \d는 숫자 +는 1개 이상
df['설치용량'].str.extract(r'(\d+.\d+)')
# Out:
#           0
# 0       196
# 1     809.2
# 2     110.5
# 3     1,400
# 4    501.84
# 5       187
# 6       390
# 7       115
# 8       834
# 9       995
# 10    2,599
# 11      241
# 12    2,002
# 13   990.45
# 14      999
# 15   996.93
# 16    296.1
# 17    1,742
# 18    302.4
# 19     63.0
# 20      200
# 21   605.55
# 22    907.2
# 23   990.72
# 24    284.7
# 25    97.92
# 26      175
# 27    1,190
# 28   994.84
# 29      998
# 30   888.93
# 31   369.85
# 32      250
# 33     48.3
# 34    93.02
# 35      250
# 36    998.4
# 37   1900.8
# 38    600.6
# 39   997.56
# 40   997.56
# 41  998.325
# 42    999.6
# 43      233
# 44    554.4

# %%
# 첫 열 데이터 추출 
df['설치용량'].str.extract(r'(\d+.\d+)')[0]
# Out:
# 0         196
# 1       809.2
# 2       110.5
# 3       1,400
# 4      501.84
# 5         187
# 6         390
# 7         115
# 8         834
# 9         995
# 10      2,599
# 11        241
# 12      2,002
# 13     990.45
# 14        999
# 15     996.93
# 16      296.1
# 17      1,742
# 18      302.4
# 19       63.0
# 20        200
# 21     605.55
# 22      907.2
# 23     990.72
# 24      284.7
# 25      97.92
# 26        175
# 27      1,190
# 28     994.84
# 29        998
# 30     888.93
# 31     369.85
# 32        250
# 33       48.3
# 34      93.02
# 35        250
# 36      998.4
# 37     1900.8
# 38      600.6
# 39     997.56
# 40     997.56
# 41    998.325
# 42      999.6
# 43        233
# 44      554.4
# Name: 0, dtype: object

# %%
# 쉼표를 삭제
df['설치용량'].str.extract(r'(\d+.\d+)')[0].str.replace(',','')
# Out:
# 0         196
# 1       809.2
# 2       110.5
# 3        1400
# 4      501.84
# 5         187
# 6         390
# 7         115
# 8         834
# 9         995
# 10       2599
# 11        241
# 12       2002
# 13     990.45
# 14        999
# 15     996.93
# 16      296.1
# 17       1742
# 18      302.4
# 19       63.0
# 20        200
# 21     605.55
# 22      907.2
# 23     990.72
# 24      284.7
# 25      97.92
# 26        175
# 27       1190
# 28     994.84
# 29        998
# 30     888.93
# 31     369.85
# 32        250
# 33       48.3
# 34      93.02
# 35        250
# 36      998.4
# 37     1900.8
# 38      600.6
# 39     997.56
# 40     997.56
# 41    998.325
# 42      999.6
# 43        233
# 44      554.4
# Name: 0, dtype: object

# %%
#숫자로 변화: 소수점 첫자리에서 반울림 후 정수로 변환
pd.to_numeric(df['설치용량'].str.extract(r'(\d+.\d+)')[0].str.replace(',','')).round(0).astype(int)
# Out:
# 0      196
# 1      809
# 2      110
# 3     1400
# 4      502
# 5      187
# 6      390
# 7      115
# 8      834
# 9      995
# 10    2599
# 11     241
# 12    2002
# 13     990
# 14     999
# 15     997
# 16     296
# 17    1742
# 18     302
# 19      63
# 20     200
# 21     606
# 22     907
# 23     991
# 24     285
# 25      98
# 26     175
# 27    1190
# 28     995
# 29     998
# 30     889
# 31     370
# 32     250
# 33      48
# 34      93
# 35     250
# 36     998
# 37    1901
# 38     601
# 39     998
# 40     998
# 41     998
# 42    1000
# 43     233
# 44     554
# Name: 0, dtype: int32

# %% [markdown]
# #### 방법 2) 문자열 처리 이용

# %%
#공백 문자로 문자열 분리하고 첫열 데이터 가져옴
# expand=True -- 표로 나눔
df['설치용량'].str.split(' ',expand=True)[0]
# Out:
# 0           196kW
# 1         809.2kW
# 2         110.5kW
# 3     1,400.475kW
# 4        501.84kW
# 5           187kW
# 6           390kW
# 7           115kW
# 8           834kW
# 9           995kW
# 10      2,599.2kW
# 11          241kW
# 12     2,002.32kW
# 13     990.45kW모듈
# 14          999kW
# 15       996.93kW
# 16        296.1kW
# 17        1,742kW
# 18        302.4kW
# 19         63.0kW
# 20          200kW
# 21       605.55kW
# 22        907.2kW
# 23       990.72kW
# 24        284.7kW
# 25      97.92kW모듈
# 26           76kW
# 27      1,190.7kW
# 28       994.84kW
# 29          998kW
# 30       888.93kW
# 31       369.85kW
# 32           40kW
# 33         48.3kW
# 34        93.02kW
# 35           55kW
# 36        998.4kW
# 37       1900.8kW
# 38        600.6kW
# 39     997.56kW모듈
# 40        997.56W
# 41      998.325kW
# 42        999.6kW
# 43            6kW
# 44        554.4kW
# Name: 0, dtype: object

# %%
# 필요없는 문자 삭제
pd.to_numeric(df['설치용량'].str.split(' ',expand=True)[0].str.replace('모듈','').str.replace('kW','').str.replace('W','').str.replace(',','')).round(0).astype(int)
# Out:
# 0      196
# 1      809
# 2      110
# 3     1400
# 4      502
# 5      187
# 6      390
# 7      115
# 8      834
# 9      995
# 10    2599
# 11     241
# 12    2002
# 13     990
# 14     999
# 15     997
# 16     296
# 17    1742
# 18     302
# 19      63
# 20     200
# 21     606
# 22     907
# 23     991
# 24     285
# 25      98
# 26      76
# 27    1191
# 28     995
# 29     998
# 30     889
# 31     370
# 32      40
# 33      48
# 34      93
# 35      55
# 36     998
# 37    1901
# 38     601
# 39     998
# 40     998
# 41     998
# 42    1000
# 43       6
# 44     554
# Name: 0, dtype: int32

# %%
df['설비용량']=pd.to_numeric(df['설치용량'].str.extract(r'(\d+.\d+)')[0].str.replace(',','')).round(0).astype(int)
df
# Out:
#                      발전소명                                            발전소 주소지  \
# 0                남제주소내태양광                        제주도 서귀포시 안덕면 화순해안로 106번길 55
# 1             무릉리 태양광(제주)                      제주도 서귀포시 대정읍 무릉리 1193-3 외 3필지
# 2        부산 수처리 건물 태양광발전소                         부산광역시 사하구 감천항로 7(감천동) 수처리실
# 3   부산발전본부 1,400kW 태양광발전소                              부산광역시 사하구 감천항로 7(감천동)
# 4            부산복합 2단계 태양광                              부산광역시 사하구 감천항로 7(감천동)
# 5        부산복합 자재창고 태양광발전소                              부산광역시 사하구 감천항로 7(감천동)
# 6                 부산복합태양광                                   부산광역시 사하구 감천항로 7
# 7                 부산신항태양광                                 부산광역시 강서구 성북동 1490
# 8              부산역 선상 주차장                              부산광역시 동구 초량3동 1187-1
# 9           이천D(백사면B) 태양광                              경기도 이천시 백사면 도립리 141-1
# 10             삼척 소내태양광#4                                강원도 삼척시 원덕읍 삼척로 734
# 11               삼척사택 태양광                     강원도 삼척시 원덕읍 삼척로 581-7 삼척그린파워사택
# 12            삼척소내 태양광# 3                                강원도 삼척시 원덕읍 삼척로 734
# 13             삼척소내태양광 #2                                강원도 삼척시 원덕읍 삼척로 734
# 14              삼척소내태양광#1                                강원도 삼척시 원덕읍 삼척로 734
# 15            송당리 태양광(제주)                               제주도 제주시 구좌읍 송당리 2455
# 16       신인천 1,2단계주차장 태양광                              인천광역시 서구 장도로 57 (청라동)
# 17    신인천 법사면 전망대 태양광 발전소                              인천광역시 서구 장도로 57 (청라동)
# 18           신인천 북측부지 태양광                              인천광역시 서구 장도로 57 (청라동)
# 19           신인천 본관옥상 태양광                              인천광역시 서구 장도로 57 (청라동)
# 20         신인천 소내 태양광 발전소                              인천광역시 서구 장도로 57 (청라동)
# 21        신인천 주차장 태양광 발전소                              인천광역시 서구 장도로 57 (청라동)
# 22          신인천 해수취수구 태양광                              인천광역시 서구 장도로 57 (청라동)
# 23            신풍리 태양광(제주)                              제주도 서귀포시 성산읍 신풍리 1522
# 24         안동발전본부 2단계 태양광                            경상북도 안동시 풍산읍 산업단지 1길 38
# 25          안동발전본부 태양광발전소                            경상북도 안동시 풍산읍 산업단지 1길 38
# 26                영월복합태양광                                강원도 영월군 영월읍 중앙로 411
# 27             영월철도부지 태양광                    강원도 영월군 영월읍 중앙로 411 정양리 일원(585)
# 28             위미2리 제2태양광                      제주도 제주특별자치도 서귀포시 남원읍 위미리 3696
# 29             인천수산정수장태양광                                인천광역시 남동구 수산동 294-4
# 30             제주 용수리 태양광                            제주도 제주시 한경면 용수리 457 외 2
# 31             하동공설운동장태양광                            경상남도 하동군 적량면 고절리 1209-1
# 32              하동군보건소태양광                             경상남도 하동군 하동읍 읍내리 149-1
# 33               하동변전소태양광                               경상남도 하동군 적량면 동산리 867
# 34               하동정수장태양광                               경상남도 하동군 하동읍 두곡리 543
# 35             하동하수처리장태양광                               경상남도 하동군 하동읍 신기리 2-2
# 36             하동화력태양광 #1                               경상남도 하동군 금성면 가덕리 310
# 37             하동화력태양광 #2                               경상남도 하동군 금성면 가덕리 310
# 38             하동화력태양광 #3                               경상남도 하동군 금성면 가덕리 310
# 39             하동화력태양광 #4  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 40             하동화력태양광 #5  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 41             하동화력태양광 #6                          경상남도 하동군 금성면 가덕리 1321,309
# 42         화촌주민참여형솔라팜 태양광                      경상남도 하동군 양보면 지례리 183-5 외 10필지
# 43               행원소수력태양광                              제주도 제주시 구좌읍 행원리 571-2
# 44                감우리 태양광                         충청북도 충북 음성군 음성읍 감우리 23, 24
#
#                                                  설치용량  \
# 0              196kW 모듈 :250W x 784 인버터 : 100kW x 2EA
# 1         809.2kW 모듈 : 425W  x 1904 인버터 : 100kW x 8EA
# 2           110.5kW 모듈 : 340Wⅹ325 인버터 : 100kW, 10.5kW
# 3         1,400.475kW 모듈 : 355Wⅹ3,945 인버터 : 500kWⅹ3EA
# 4        501.84kW 모듈 : 340W x 1,476 인버터 : 600kW x 1EA
# 5               187kW 모듈 : 300Wⅹ624 인버터 : 100kW x 2EA
# 6   390kW 모듈 :170W x 1,155 인버터 : 100kW x 3EA, 50kW...
# 7   115kW 모듈 :144Wp x 272, 100Wp x 384, 215Wp x 17...
# 8           834kW 모듈 : 400W x 2086, 인버터 : 500kW x 2EA
# 9           995kW 모듈 : 440W x 2272, 인버터 : 500kW X 2EA
# 10       2,599.2kW 모듈 : 380Wⅹ6,840 인버터 : 1250kW x 2EA
# 11  241kW 모듈 : 250ⅹ964 인버터 : 36kWⅹ2, 41kWⅹ1, 46kWⅹ...
# 12  2,002.32kW 모듈 : 360Wⅹ5,562 인버터 : 500kWⅹ1EA, 15...
# 13           990.45kW모듈 : 355Wⅹ2,790 인버터 : 500kWⅹ2EA
# 14              999kW 모듈 : 360Wⅹ2,775 인버터 : 500kWⅹ2EA
# 15      996.93kW 모듈 : 330W ⅹ 3,021 인버터 : 105kW ⅹ 10EA
# 16          296.1kW 모듈 : 450W x 658 인버터 : 100kW x 3EA
# 17         1,742kW 모듈 :475W x 3,668 인버터 : 250kW x 7EA
# 18          302.4kW 모듈 : 450W x 672 인버터 : 100kW x 3EA
# 19           63.0kW 모듈 : 450W x 140 인버터 : 100kW x 1EA
# 20            200kW 모듈 : 250W x 800 인버터 : 210kW x 1EA
# 21  605.55kW 모듈 : 390W X1,545 인버터 : 100kW x 6EA, 3...
# 22        907.2kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 23       990.72kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 24          284.7kW 모듈 : 365W x 780 인버터 : 100kW x 3EA
# 25                  97.92kW모듈 : 340Wⅹ288 인버터 : 99.4kW
# 26  76kW 모듈 :175W x 432 인버터 : 30.21kVA x 2EA, 20kV...
# 27          1,190.7kW 모듈 : 350Wⅹ3,402 인버터 : 600kWⅹ2EA
# 28       994.84kW 모듈 : 340W x 2,926 인버터 : 500kW x 2EA
# 29           998kW 모듈 :230W x 4,284 인버터 : 250kW x 4EA
# 30       888.93kW 모듈 : 415W x 2,142 인버터 : 105kW x 9EA
# 31  369.85kW 모듈 :250W x 980, 144W x 867  인버터 : 250...
# 32               40kW 모듈 :250W x 220 인버터 : 40kW x 1EA
# 33             48.3kW 모듈 :230W x 210 인버터 : 50kW x 1EA
# 34           93.02kW 모듈 :144W x 646 인버터 : 100kW x 1EA
# 35               55kW 모듈 :250W x 160 인버터 : 55kW x 1EA
# 36         998.4kW 모듈 :160W x 6,256 인버터 : 250kW x 5EA
# 37  1900.8kW 모듈 :100/144/160/230W x 11,196 인버터 : 1...
# 38         600.6kW 모듈 :220W x 2,730 인버터 : 100kW x 7EA
# 39            997.56kW모듈 : 340Wⅹ2,934 인버터 : 500kWⅹ2EA
# 40        997.56W 모듈 : 340W x 2,934 인버터 : 500kW x 2EA
# 41       998.325kW 모듈 : 435W x 2295 인버터 : 500kW x 2EA
# 42        999.6kW 모듈 : 420W x 2380 인버터 : 100kW x 10EA
# 43                 6kW 모듈 :233W x 25 인버터 : 10kW x 1EA
# 44        554.4kW 모듈 : 440W x 1,260 인버터 : 630kW x 1EA
#
#                                설치각  설비용량
# 0                        설치각 : 30˚   196
# 1                        설치각 : 20˚   809
# 2              설치각 : 25˚ 입사각 : 23˚   110
# 3                        설치각 : 25˚  1400
# 4                        설치각 : 25˚   502
# 5                        설치각 : 27˚   187
# 6                    설치각 : 21˚~45˚   390
# 7                        설치각 : 17˚   115
# 8                     설치각 : 3˚~23˚   834
# 9                        설치각 : 25˚   995
# 10                       설치각 : 25˚  2599
# 11                       사택 지붕에 설치   241
# 12                       설치각 : 25˚  2002
# 13                       설치각 : 25˚   990
# 14  설치각 : 25˚(지면경사 : 0˚) 입사각 : 23˚   999
# 15                       설치각 : 24˚   997
# 16                       설치각 : 15˚   296
# 17                       설치각 : 20˚  1742
# 18                       설치각 : 18˚   302
# 19                       설치각 : 25˚    63
# 20                     설치각 : 8~45˚   200
# 21              설치각 : 25˚, 10˚~20˚   606
# 22                       설치각 : 23˚   907
# 23                       설치각 : 24˚   991
# 24                       설치각 : 21˚   285
# 25                       설치각 : 25˚    98
# 26                       설치각 : 26˚   175
# 27  설치각 : 30˚(지면경사 : 0˚) 입사각 : 25˚  1190
# 28                       설치각 : 25˚   995
# 29                       설치각 : 23˚   998
# 30                       설치각 : 18˚   889
# 31                       설치각 : 30˚   370
# 32                       설치각 : 30˚   250
# 33                       설치각 : 30˚    48
# 34                          지붕에 설치    93
# 35                       설치각 : 30˚   250
# 36                       설치각 : 32˚   998
# 37                       설치각 : 32˚  1901
# 38                       설치각 : 32˚   601
# 39             설치각 : 30˚ 입사각 : 23˚   998
# 40                       설치각 : 30˚   998
# 41                       설치각 : 22˚   998
# 42                       설치각 : 20˚  1000
# 43                       설치각 : 30˚   233
# 44                       설치각 : 20˚   554

# %% [markdown]
# ### 2) 발전소명 정리

# %%
# '발전소', '태양광' 문자열 삭제 후 오른쪽 공백 문자 삭제
df['발전소명'].str.replace('발전소','').str.replace('태양광','').str.rstrip()
df['발전소명']=df['발전소명'].str.replace('발전소','').str.replace('태양광','').str.rstrip()
df
# Out:
#               발전소명                                            발전소 주소지  \
# 0            남제주소내                        제주도 서귀포시 안덕면 화순해안로 106번길 55
# 1         무릉리 (제주)                      제주도 서귀포시 대정읍 무릉리 1193-3 외 3필지
# 2        부산 수처리 건물                         부산광역시 사하구 감천항로 7(감천동) 수처리실
# 3   부산발전본부 1,400kW                              부산광역시 사하구 감천항로 7(감천동)
# 4         부산복합 2단계                              부산광역시 사하구 감천항로 7(감천동)
# 5        부산복합 자재창고                              부산광역시 사하구 감천항로 7(감천동)
# 6             부산복합                                   부산광역시 사하구 감천항로 7
# 7             부산신항                                 부산광역시 강서구 성북동 1490
# 8       부산역 선상 주차장                              부산광역시 동구 초량3동 1187-1
# 9        이천D(백사면B)                              경기도 이천시 백사면 도립리 141-1
# 10         삼척 소내#4                                강원도 삼척시 원덕읍 삼척로 734
# 11            삼척사택                     강원도 삼척시 원덕읍 삼척로 581-7 삼척그린파워사택
# 12        삼척소내 # 3                                강원도 삼척시 원덕읍 삼척로 734
# 13         삼척소내 #2                                강원도 삼척시 원덕읍 삼척로 734
# 14          삼척소내#1                                강원도 삼척시 원덕읍 삼척로 734
# 15        송당리 (제주)                               제주도 제주시 구좌읍 송당리 2455
# 16    신인천 1,2단계주차장                              인천광역시 서구 장도로 57 (청라동)
# 17     신인천 법사면 전망대                              인천광역시 서구 장도로 57 (청라동)
# 18        신인천 북측부지                              인천광역시 서구 장도로 57 (청라동)
# 19        신인천 본관옥상                              인천광역시 서구 장도로 57 (청라동)
# 20          신인천 소내                              인천광역시 서구 장도로 57 (청라동)
# 21         신인천 주차장                              인천광역시 서구 장도로 57 (청라동)
# 22       신인천 해수취수구                              인천광역시 서구 장도로 57 (청라동)
# 23        신풍리 (제주)                              제주도 서귀포시 성산읍 신풍리 1522
# 24      안동발전본부 2단계                            경상북도 안동시 풍산읍 산업단지 1길 38
# 25          안동발전본부                            경상북도 안동시 풍산읍 산업단지 1길 38
# 26            영월복합                                강원도 영월군 영월읍 중앙로 411
# 27          영월철도부지                    강원도 영월군 영월읍 중앙로 411 정양리 일원(585)
# 28         위미2리 제2                      제주도 제주특별자치도 서귀포시 남원읍 위미리 3696
# 29         인천수산정수장                                인천광역시 남동구 수산동 294-4
# 30          제주 용수리                            제주도 제주시 한경면 용수리 457 외 2
# 31         하동공설운동장                            경상남도 하동군 적량면 고절리 1209-1
# 32          하동군보건소                             경상남도 하동군 하동읍 읍내리 149-1
# 33           하동변전소                               경상남도 하동군 적량면 동산리 867
# 34           하동정수장                               경상남도 하동군 하동읍 두곡리 543
# 35         하동하수처리장                               경상남도 하동군 하동읍 신기리 2-2
# 36         하동화력 #1                               경상남도 하동군 금성면 가덕리 310
# 37         하동화력 #2                               경상남도 하동군 금성면 가덕리 310
# 38         하동화력 #3                               경상남도 하동군 금성면 가덕리 310
# 39         하동화력 #4  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 40         하동화력 #5  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 41         하동화력 #6                          경상남도 하동군 금성면 가덕리 1321,309
# 42      화촌주민참여형솔라팜                      경상남도 하동군 양보면 지례리 183-5 외 10필지
# 43           행원소수력                              제주도 제주시 구좌읍 행원리 571-2
# 44             감우리                         충청북도 충북 음성군 음성읍 감우리 23, 24
#
#                                                  설치용량  \
# 0              196kW 모듈 :250W x 784 인버터 : 100kW x 2EA
# 1         809.2kW 모듈 : 425W  x 1904 인버터 : 100kW x 8EA
# 2           110.5kW 모듈 : 340Wⅹ325 인버터 : 100kW, 10.5kW
# 3         1,400.475kW 모듈 : 355Wⅹ3,945 인버터 : 500kWⅹ3EA
# 4        501.84kW 모듈 : 340W x 1,476 인버터 : 600kW x 1EA
# 5               187kW 모듈 : 300Wⅹ624 인버터 : 100kW x 2EA
# 6   390kW 모듈 :170W x 1,155 인버터 : 100kW x 3EA, 50kW...
# 7   115kW 모듈 :144Wp x 272, 100Wp x 384, 215Wp x 17...
# 8           834kW 모듈 : 400W x 2086, 인버터 : 500kW x 2EA
# 9           995kW 모듈 : 440W x 2272, 인버터 : 500kW X 2EA
# 10       2,599.2kW 모듈 : 380Wⅹ6,840 인버터 : 1250kW x 2EA
# 11  241kW 모듈 : 250ⅹ964 인버터 : 36kWⅹ2, 41kWⅹ1, 46kWⅹ...
# 12  2,002.32kW 모듈 : 360Wⅹ5,562 인버터 : 500kWⅹ1EA, 15...
# 13           990.45kW모듈 : 355Wⅹ2,790 인버터 : 500kWⅹ2EA
# 14              999kW 모듈 : 360Wⅹ2,775 인버터 : 500kWⅹ2EA
# 15      996.93kW 모듈 : 330W ⅹ 3,021 인버터 : 105kW ⅹ 10EA
# 16          296.1kW 모듈 : 450W x 658 인버터 : 100kW x 3EA
# 17         1,742kW 모듈 :475W x 3,668 인버터 : 250kW x 7EA
# 18          302.4kW 모듈 : 450W x 672 인버터 : 100kW x 3EA
# 19           63.0kW 모듈 : 450W x 140 인버터 : 100kW x 1EA
# 20            200kW 모듈 : 250W x 800 인버터 : 210kW x 1EA
# 21  605.55kW 모듈 : 390W X1,545 인버터 : 100kW x 6EA, 3...
# 22        907.2kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 23       990.72kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 24          284.7kW 모듈 : 365W x 780 인버터 : 100kW x 3EA
# 25                  97.92kW모듈 : 340Wⅹ288 인버터 : 99.4kW
# 26  76kW 모듈 :175W x 432 인버터 : 30.21kVA x 2EA, 20kV...
# 27          1,190.7kW 모듈 : 350Wⅹ3,402 인버터 : 600kWⅹ2EA
# 28       994.84kW 모듈 : 340W x 2,926 인버터 : 500kW x 2EA
# 29           998kW 모듈 :230W x 4,284 인버터 : 250kW x 4EA
# 30       888.93kW 모듈 : 415W x 2,142 인버터 : 105kW x 9EA
# 31  369.85kW 모듈 :250W x 980, 144W x 867  인버터 : 250...
# 32               40kW 모듈 :250W x 220 인버터 : 40kW x 1EA
# 33             48.3kW 모듈 :230W x 210 인버터 : 50kW x 1EA
# 34           93.02kW 모듈 :144W x 646 인버터 : 100kW x 1EA
# 35               55kW 모듈 :250W x 160 인버터 : 55kW x 1EA
# 36         998.4kW 모듈 :160W x 6,256 인버터 : 250kW x 5EA
# 37  1900.8kW 모듈 :100/144/160/230W x 11,196 인버터 : 1...
# 38         600.6kW 모듈 :220W x 2,730 인버터 : 100kW x 7EA
# 39            997.56kW모듈 : 340Wⅹ2,934 인버터 : 500kWⅹ2EA
# 40        997.56W 모듈 : 340W x 2,934 인버터 : 500kW x 2EA
# 41       998.325kW 모듈 : 435W x 2295 인버터 : 500kW x 2EA
# 42        999.6kW 모듈 : 420W x 2380 인버터 : 100kW x 10EA
# 43                 6kW 모듈 :233W x 25 인버터 : 10kW x 1EA
# 44        554.4kW 모듈 : 440W x 1,260 인버터 : 630kW x 1EA
#
#                                설치각  설비용량
# 0                        설치각 : 30˚   196
# 1                        설치각 : 20˚   809
# 2              설치각 : 25˚ 입사각 : 23˚   110
# 3                        설치각 : 25˚  1400
# 4                        설치각 : 25˚   502
# 5                        설치각 : 27˚   187
# 6                    설치각 : 21˚~45˚   390
# 7                        설치각 : 17˚   115
# 8                     설치각 : 3˚~23˚   834
# 9                        설치각 : 25˚   995
# 10                       설치각 : 25˚  2599
# 11                       사택 지붕에 설치   241
# 12                       설치각 : 25˚  2002
# 13                       설치각 : 25˚   990
# 14  설치각 : 25˚(지면경사 : 0˚) 입사각 : 23˚   999
# 15                       설치각 : 24˚   997
# 16                       설치각 : 15˚   296
# 17                       설치각 : 20˚  1742
# 18                       설치각 : 18˚   302
# 19                       설치각 : 25˚    63
# 20                     설치각 : 8~45˚   200
# 21              설치각 : 25˚, 10˚~20˚   606
# 22                       설치각 : 23˚   907
# 23                       설치각 : 24˚   991
# 24                       설치각 : 21˚   285
# 25                       설치각 : 25˚    98
# 26                       설치각 : 26˚   175
# 27  설치각 : 30˚(지면경사 : 0˚) 입사각 : 25˚  1190
# 28                       설치각 : 25˚   995
# 29                       설치각 : 23˚   998
# 30                       설치각 : 18˚   889
# 31                       설치각 : 30˚   370
# 32                       설치각 : 30˚   250
# 33                       설치각 : 30˚    48
# 34                          지붕에 설치    93
# 35                       설치각 : 30˚   250
# 36                       설치각 : 32˚   998
# 37                       설치각 : 32˚  1901
# 38                       설치각 : 32˚   601
# 39             설치각 : 30˚ 입사각 : 23˚   998
# 40                       설치각 : 30˚   998
# 41                       설치각 : 22˚   998
# 42                       설치각 : 20˚  1000
# 43                       설치각 : 30˚   233
# 44                       설치각 : 20˚   554

# %% [markdown]
# ### 3) 발전소 주소지 정리

# %%
#for add in df['발전소 주소지']:
#    print(add) 모두 
#    print(add.split()[0]) #도/시
#    print(add.split()[1]) #시/군/구

# %%
df['도/시'] = [add.split()[0] for add in df['발전소 주소지']]

# %%
df['시/군/구'] = [add.split()[1] for add in df['발전소 주소지']]

# %%
df
# Out:
#               발전소명                                            발전소 주소지  \
# 0            남제주소내                        제주도 서귀포시 안덕면 화순해안로 106번길 55
# 1         무릉리 (제주)                      제주도 서귀포시 대정읍 무릉리 1193-3 외 3필지
# 2        부산 수처리 건물                         부산광역시 사하구 감천항로 7(감천동) 수처리실
# 3   부산발전본부 1,400kW                              부산광역시 사하구 감천항로 7(감천동)
# 4         부산복합 2단계                              부산광역시 사하구 감천항로 7(감천동)
# 5        부산복합 자재창고                              부산광역시 사하구 감천항로 7(감천동)
# 6             부산복합                                   부산광역시 사하구 감천항로 7
# 7             부산신항                                 부산광역시 강서구 성북동 1490
# 8       부산역 선상 주차장                              부산광역시 동구 초량3동 1187-1
# 9        이천D(백사면B)                              경기도 이천시 백사면 도립리 141-1
# 10         삼척 소내#4                                강원도 삼척시 원덕읍 삼척로 734
# 11            삼척사택                     강원도 삼척시 원덕읍 삼척로 581-7 삼척그린파워사택
# 12        삼척소내 # 3                                강원도 삼척시 원덕읍 삼척로 734
# 13         삼척소내 #2                                강원도 삼척시 원덕읍 삼척로 734
# 14          삼척소내#1                                강원도 삼척시 원덕읍 삼척로 734
# 15        송당리 (제주)                               제주도 제주시 구좌읍 송당리 2455
# 16    신인천 1,2단계주차장                              인천광역시 서구 장도로 57 (청라동)
# 17     신인천 법사면 전망대                              인천광역시 서구 장도로 57 (청라동)
# 18        신인천 북측부지                              인천광역시 서구 장도로 57 (청라동)
# 19        신인천 본관옥상                              인천광역시 서구 장도로 57 (청라동)
# 20          신인천 소내                              인천광역시 서구 장도로 57 (청라동)
# 21         신인천 주차장                              인천광역시 서구 장도로 57 (청라동)
# 22       신인천 해수취수구                              인천광역시 서구 장도로 57 (청라동)
# 23        신풍리 (제주)                              제주도 서귀포시 성산읍 신풍리 1522
# 24      안동발전본부 2단계                            경상북도 안동시 풍산읍 산업단지 1길 38
# 25          안동발전본부                            경상북도 안동시 풍산읍 산업단지 1길 38
# 26            영월복합                                강원도 영월군 영월읍 중앙로 411
# 27          영월철도부지                    강원도 영월군 영월읍 중앙로 411 정양리 일원(585)
# 28         위미2리 제2                      제주도 제주특별자치도 서귀포시 남원읍 위미리 3696
# 29         인천수산정수장                                인천광역시 남동구 수산동 294-4
# 30          제주 용수리                            제주도 제주시 한경면 용수리 457 외 2
# 31         하동공설운동장                            경상남도 하동군 적량면 고절리 1209-1
# 32          하동군보건소                             경상남도 하동군 하동읍 읍내리 149-1
# 33           하동변전소                               경상남도 하동군 적량면 동산리 867
# 34           하동정수장                               경상남도 하동군 하동읍 두곡리 543
# 35         하동하수처리장                               경상남도 하동군 하동읍 신기리 2-2
# 36         하동화력 #1                               경상남도 하동군 금성면 가덕리 310
# 37         하동화력 #2                               경상남도 하동군 금성면 가덕리 310
# 38         하동화력 #3                               경상남도 하동군 금성면 가덕리 310
# 39         하동화력 #4  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 40         하동화력 #5  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 41         하동화력 #6                          경상남도 하동군 금성면 가덕리 1321,309
# 42      화촌주민참여형솔라팜                      경상남도 하동군 양보면 지례리 183-5 외 10필지
# 43           행원소수력                              제주도 제주시 구좌읍 행원리 571-2
# 44             감우리                         충청북도 충북 음성군 음성읍 감우리 23, 24
#
#                                                  설치용량  \
# 0              196kW 모듈 :250W x 784 인버터 : 100kW x 2EA
# 1         809.2kW 모듈 : 425W  x 1904 인버터 : 100kW x 8EA
# 2           110.5kW 모듈 : 340Wⅹ325 인버터 : 100kW, 10.5kW
# 3         1,400.475kW 모듈 : 355Wⅹ3,945 인버터 : 500kWⅹ3EA
# 4        501.84kW 모듈 : 340W x 1,476 인버터 : 600kW x 1EA
# 5               187kW 모듈 : 300Wⅹ624 인버터 : 100kW x 2EA
# 6   390kW 모듈 :170W x 1,155 인버터 : 100kW x 3EA, 50kW...
# 7   115kW 모듈 :144Wp x 272, 100Wp x 384, 215Wp x 17...
# 8           834kW 모듈 : 400W x 2086, 인버터 : 500kW x 2EA
# 9           995kW 모듈 : 440W x 2272, 인버터 : 500kW X 2EA
# 10       2,599.2kW 모듈 : 380Wⅹ6,840 인버터 : 1250kW x 2EA
# 11  241kW 모듈 : 250ⅹ964 인버터 : 36kWⅹ2, 41kWⅹ1, 46kWⅹ...
# 12  2,002.32kW 모듈 : 360Wⅹ5,562 인버터 : 500kWⅹ1EA, 15...
# 13           990.45kW모듈 : 355Wⅹ2,790 인버터 : 500kWⅹ2EA
# 14              999kW 모듈 : 360Wⅹ2,775 인버터 : 500kWⅹ2EA
# 15      996.93kW 모듈 : 330W ⅹ 3,021 인버터 : 105kW ⅹ 10EA
# 16          296.1kW 모듈 : 450W x 658 인버터 : 100kW x 3EA
# 17         1,742kW 모듈 :475W x 3,668 인버터 : 250kW x 7EA
# 18          302.4kW 모듈 : 450W x 672 인버터 : 100kW x 3EA
# 19           63.0kW 모듈 : 450W x 140 인버터 : 100kW x 1EA
# 20            200kW 모듈 : 250W x 800 인버터 : 210kW x 1EA
# 21  605.55kW 모듈 : 390W X1,545 인버터 : 100kW x 6EA, 3...
# 22        907.2kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 23       990.72kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 24          284.7kW 모듈 : 365W x 780 인버터 : 100kW x 3EA
# 25                  97.92kW모듈 : 340Wⅹ288 인버터 : 99.4kW
# 26  76kW 모듈 :175W x 432 인버터 : 30.21kVA x 2EA, 20kV...
# 27          1,190.7kW 모듈 : 350Wⅹ3,402 인버터 : 600kWⅹ2EA
# 28       994.84kW 모듈 : 340W x 2,926 인버터 : 500kW x 2EA
# 29           998kW 모듈 :230W x 4,284 인버터 : 250kW x 4EA
# 30       888.93kW 모듈 : 415W x 2,142 인버터 : 105kW x 9EA
# 31  369.85kW 모듈 :250W x 980, 144W x 867  인버터 : 250...
# 32               40kW 모듈 :250W x 220 인버터 : 40kW x 1EA
# 33             48.3kW 모듈 :230W x 210 인버터 : 50kW x 1EA
# 34           93.02kW 모듈 :144W x 646 인버터 : 100kW x 1EA
# 35               55kW 모듈 :250W x 160 인버터 : 55kW x 1EA
# 36         998.4kW 모듈 :160W x 6,256 인버터 : 250kW x 5EA
# 37  1900.8kW 모듈 :100/144/160/230W x 11,196 인버터 : 1...
# 38         600.6kW 모듈 :220W x 2,730 인버터 : 100kW x 7EA
# 39            997.56kW모듈 : 340Wⅹ2,934 인버터 : 500kWⅹ2EA
# 40        997.56W 모듈 : 340W x 2,934 인버터 : 500kW x 2EA
# 41       998.325kW 모듈 : 435W x 2295 인버터 : 500kW x 2EA
# 42        999.6kW 모듈 : 420W x 2380 인버터 : 100kW x 10EA
# 43                 6kW 모듈 :233W x 25 인버터 : 10kW x 1EA
# 44        554.4kW 모듈 : 440W x 1,260 인버터 : 630kW x 1EA
#
#                                설치각  설비용량    도/시    시/군/구
# 0                        설치각 : 30˚   196    제주도     서귀포시
# 1                        설치각 : 20˚   809    제주도     서귀포시
# 2              설치각 : 25˚ 입사각 : 23˚   110  부산광역시      사하구
# 3                        설치각 : 25˚  1400  부산광역시      사하구
# 4                        설치각 : 25˚   502  부산광역시      사하구
# 5                        설치각 : 27˚   187  부산광역시      사하구
# 6                    설치각 : 21˚~45˚   390  부산광역시      사하구
# 7                        설치각 : 17˚   115  부산광역시      강서구
# 8                     설치각 : 3˚~23˚   834  부산광역시       동구
# 9                        설치각 : 25˚   995    경기도      이천시
# 10                       설치각 : 25˚  2599    강원도      삼척시
# 11                       사택 지붕에 설치   241    강원도      삼척시
# 12                       설치각 : 25˚  2002    강원도      삼척시
# 13                       설치각 : 25˚   990    강원도      삼척시
# 14  설치각 : 25˚(지면경사 : 0˚) 입사각 : 23˚   999    강원도      삼척시
# 15                       설치각 : 24˚   997    제주도      제주시
# 16                       설치각 : 15˚   296  인천광역시       서구
# 17                       설치각 : 20˚  1742  인천광역시       서구
# 18                       설치각 : 18˚   302  인천광역시       서구
# 19                       설치각 : 25˚    63  인천광역시       서구
# 20                     설치각 : 8~45˚   200  인천광역시       서구
# 21              설치각 : 25˚, 10˚~20˚   606  인천광역시       서구
# 22                       설치각 : 23˚   907  인천광역시       서구
# 23                       설치각 : 24˚   991    제주도     서귀포시
# 24                       설치각 : 21˚   285   경상북도      안동시
# 25                       설치각 : 25˚    98   경상북도      안동시
# 26                       설치각 : 26˚   175    강원도      영월군
# 27  설치각 : 30˚(지면경사 : 0˚) 입사각 : 25˚  1190    강원도      영월군
# 28                       설치각 : 25˚   995    제주도  제주특별자치도
# 29                       설치각 : 23˚   998  인천광역시      남동구
# 30                       설치각 : 18˚   889    제주도      제주시
# 31                       설치각 : 30˚   370   경상남도      하동군
# 32                       설치각 : 30˚   250   경상남도      하동군
# 33                       설치각 : 30˚    48   경상남도      하동군
# 34                          지붕에 설치    93   경상남도      하동군
# 35                       설치각 : 30˚   250   경상남도      하동군
# 36                       설치각 : 32˚   998   경상남도      하동군
# 37                       설치각 : 32˚  1901   경상남도      하동군
# 38                       설치각 : 32˚   601   경상남도      하동군
# 39             설치각 : 30˚ 입사각 : 23˚   998   경상남도      하동군
# 40                       설치각 : 30˚   998   경상남도      하동군
# 41                       설치각 : 22˚   998   경상남도      하동군
# 42                       설치각 : 20˚  1000   경상남도      하동군
# 43                       설치각 : 30˚   233    제주도      제주시
# 44                       설치각 : 20˚   554   충청북도       충북

# %% [markdown]
# ## 3. 지역별 설비용량 분석

# %% [markdown]
# ### 3.1 발전소별 설비용량 지도 시각화

# %% [markdown]
# #### 1) 도/시 행정구역벼 위도, 경도 추가

# %%
from geopy.geocoders import Nominatim

#한글 주소를 지오코딩
geo_local = Nominatim(user_agent = 'South Korea')

#위도 경도 반환 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude,geo.longitude]
        return x_y
    except:
        return[0,0]

# %%
geo_local.geocode('제주도')
# Out:
# Location(제주도, 성판악코스, 제주시, 제주특별자치도, 대한민국, (33.3939924, 126.5626653, 0.0))

# %%
geocoding('인천광역시')
# Out:
# [0, 0]

# %%
#주소를 위도, 경도로 변환하는 함수
def convert_lat_lng(add):
    
    lat=[]
    lng=[]
    
    for i in add.tolist():
        lat.append(geocoding(i)[0])
        lng.append(geocoding(i)[1])
        
    return lat, lng

# %%
lat_do, lng_do = convert_lat_lng(df['도/시'])
df['lat_do'] = lat_do
df['lng_do'] = lng_do

# %%
df
# Out:
#               발전소명                                            발전소 주소지  \
# 0            남제주소내                        제주도 서귀포시 안덕면 화순해안로 106번길 55
# 1         무릉리 (제주)                      제주도 서귀포시 대정읍 무릉리 1193-3 외 3필지
# 2        부산 수처리 건물                         부산광역시 사하구 감천항로 7(감천동) 수처리실
# 3   부산발전본부 1,400kW                              부산광역시 사하구 감천항로 7(감천동)
# 4         부산복합 2단계                              부산광역시 사하구 감천항로 7(감천동)
# 5        부산복합 자재창고                              부산광역시 사하구 감천항로 7(감천동)
# 6             부산복합                                   부산광역시 사하구 감천항로 7
# 7             부산신항                                 부산광역시 강서구 성북동 1490
# 8       부산역 선상 주차장                              부산광역시 동구 초량3동 1187-1
# 9        이천D(백사면B)                              경기도 이천시 백사면 도립리 141-1
# 10         삼척 소내#4                                강원도 삼척시 원덕읍 삼척로 734
# 11            삼척사택                     강원도 삼척시 원덕읍 삼척로 581-7 삼척그린파워사택
# 12        삼척소내 # 3                                강원도 삼척시 원덕읍 삼척로 734
# 13         삼척소내 #2                                강원도 삼척시 원덕읍 삼척로 734
# 14          삼척소내#1                                강원도 삼척시 원덕읍 삼척로 734
# 15        송당리 (제주)                               제주도 제주시 구좌읍 송당리 2455
# 16    신인천 1,2단계주차장                              인천광역시 서구 장도로 57 (청라동)
# 17     신인천 법사면 전망대                              인천광역시 서구 장도로 57 (청라동)
# 18        신인천 북측부지                              인천광역시 서구 장도로 57 (청라동)
# 19        신인천 본관옥상                              인천광역시 서구 장도로 57 (청라동)
# 20          신인천 소내                              인천광역시 서구 장도로 57 (청라동)
# 21         신인천 주차장                              인천광역시 서구 장도로 57 (청라동)
# 22       신인천 해수취수구                              인천광역시 서구 장도로 57 (청라동)
# 23        신풍리 (제주)                              제주도 서귀포시 성산읍 신풍리 1522
# 24      안동발전본부 2단계                            경상북도 안동시 풍산읍 산업단지 1길 38
# 25          안동발전본부                            경상북도 안동시 풍산읍 산업단지 1길 38
# 26            영월복합                                강원도 영월군 영월읍 중앙로 411
# 27          영월철도부지                    강원도 영월군 영월읍 중앙로 411 정양리 일원(585)
# 28         위미2리 제2                      제주도 제주특별자치도 서귀포시 남원읍 위미리 3696
# 29         인천수산정수장                                인천광역시 남동구 수산동 294-4
# 30          제주 용수리                            제주도 제주시 한경면 용수리 457 외 2
# 31         하동공설운동장                            경상남도 하동군 적량면 고절리 1209-1
# 32          하동군보건소                             경상남도 하동군 하동읍 읍내리 149-1
# 33           하동변전소                               경상남도 하동군 적량면 동산리 867
# 34           하동정수장                               경상남도 하동군 하동읍 두곡리 543
# 35         하동하수처리장                               경상남도 하동군 하동읍 신기리 2-2
# 36         하동화력 #1                               경상남도 하동군 금성면 가덕리 310
# 37         하동화력 #2                               경상남도 하동군 금성면 가덕리 310
# 38         하동화력 #3                               경상남도 하동군 금성면 가덕리 310
# 39         하동화력 #4  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 40         하동화력 #5  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 41         하동화력 #6                          경상남도 하동군 금성면 가덕리 1321,309
# 42      화촌주민참여형솔라팜                      경상남도 하동군 양보면 지례리 183-5 외 10필지
# 43           행원소수력                              제주도 제주시 구좌읍 행원리 571-2
# 44             감우리                         충청북도 충북 음성군 음성읍 감우리 23, 24
#
#                                                  설치용량  \
# 0              196kW 모듈 :250W x 784 인버터 : 100kW x 2EA
# 1         809.2kW 모듈 : 425W  x 1904 인버터 : 100kW x 8EA
# 2           110.5kW 모듈 : 340Wⅹ325 인버터 : 100kW, 10.5kW
# 3         1,400.475kW 모듈 : 355Wⅹ3,945 인버터 : 500kWⅹ3EA
# 4        501.84kW 모듈 : 340W x 1,476 인버터 : 600kW x 1EA
# 5               187kW 모듈 : 300Wⅹ624 인버터 : 100kW x 2EA
# 6   390kW 모듈 :170W x 1,155 인버터 : 100kW x 3EA, 50kW...
# 7   115kW 모듈 :144Wp x 272, 100Wp x 384, 215Wp x 17...
# 8           834kW 모듈 : 400W x 2086, 인버터 : 500kW x 2EA
# 9           995kW 모듈 : 440W x 2272, 인버터 : 500kW X 2EA
# 10       2,599.2kW 모듈 : 380Wⅹ6,840 인버터 : 1250kW x 2EA
# 11  241kW 모듈 : 250ⅹ964 인버터 : 36kWⅹ2, 41kWⅹ1, 46kWⅹ...
# 12  2,002.32kW 모듈 : 360Wⅹ5,562 인버터 : 500kWⅹ1EA, 15...
# 13           990.45kW모듈 : 355Wⅹ2,790 인버터 : 500kWⅹ2EA
# 14              999kW 모듈 : 360Wⅹ2,775 인버터 : 500kWⅹ2EA
# 15      996.93kW 모듈 : 330W ⅹ 3,021 인버터 : 105kW ⅹ 10EA
# 16          296.1kW 모듈 : 450W x 658 인버터 : 100kW x 3EA
# 17         1,742kW 모듈 :475W x 3,668 인버터 : 250kW x 7EA
# 18          302.4kW 모듈 : 450W x 672 인버터 : 100kW x 3EA
# 19           63.0kW 모듈 : 450W x 140 인버터 : 100kW x 1EA
# 20            200kW 모듈 : 250W x 800 인버터 : 210kW x 1EA
# 21  605.55kW 모듈 : 390W X1,545 인버터 : 100kW x 6EA, 3...
# 22        907.2kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 23       990.72kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 24          284.7kW 모듈 : 365W x 780 인버터 : 100kW x 3EA
# 25                  97.92kW모듈 : 340Wⅹ288 인버터 : 99.4kW
# 26  76kW 모듈 :175W x 432 인버터 : 30.21kVA x 2EA, 20kV...
# 27          1,190.7kW 모듈 : 350Wⅹ3,402 인버터 : 600kWⅹ2EA
# 28       994.84kW 모듈 : 340W x 2,926 인버터 : 500kW x 2EA
# 29           998kW 모듈 :230W x 4,284 인버터 : 250kW x 4EA
# 30       888.93kW 모듈 : 415W x 2,142 인버터 : 105kW x 9EA
# 31  369.85kW 모듈 :250W x 980, 144W x 867  인버터 : 250...
# 32               40kW 모듈 :250W x 220 인버터 : 40kW x 1EA
# 33             48.3kW 모듈 :230W x 210 인버터 : 50kW x 1EA
# 34           93.02kW 모듈 :144W x 646 인버터 : 100kW x 1EA
# 35               55kW 모듈 :250W x 160 인버터 : 55kW x 1EA
# 36         998.4kW 모듈 :160W x 6,256 인버터 : 250kW x 5EA
# 37  1900.8kW 모듈 :100/144/160/230W x 11,196 인버터 : 1...
# 38         600.6kW 모듈 :220W x 2,730 인버터 : 100kW x 7EA
# 39            997.56kW모듈 : 340Wⅹ2,934 인버터 : 500kWⅹ2EA
# 40        997.56W 모듈 : 340W x 2,934 인버터 : 500kW x 2EA
# 41       998.325kW 모듈 : 435W x 2295 인버터 : 500kW x 2EA
# 42        999.6kW 모듈 : 420W x 2380 인버터 : 100kW x 10EA
# 43                 6kW 모듈 :233W x 25 인버터 : 10kW x 1EA
# 44        554.4kW 모듈 : 440W x 1,260 인버터 : 630kW x 1EA
#
#                                설치각  설비용량    도/시    시/군/구     lat_do  \
# 0                        설치각 : 30˚   196    제주도     서귀포시   0.000000
# 1                        설치각 : 20˚   809    제주도     서귀포시  33.393992
# 2              설치각 : 25˚ 입사각 : 23˚   110  부산광역시      사하구  35.179953
# 3                        설치각 : 25˚  1400  부산광역시      사하구  35.179953
# 4                        설치각 : 25˚   502  부산광역시      사하구  35.179953
# 5                        설치각 : 27˚   187  부산광역시      사하구  35.179953
# 6                    설치각 : 21˚~45˚   390  부산광역시      사하구  35.179953
# 7                        설치각 : 17˚   115  부산광역시      강서구  35.179953
# 8                     설치각 : 3˚~23˚   834  부산광역시       동구  35.179953
# 9                        설치각 : 25˚   995    경기도      이천시  37.275200
# 10                       설치각 : 25˚  2599    강원도      삼척시  37.885000
# 11                       사택 지붕에 설치   241    강원도      삼척시  37.885000
# 12                       설치각 : 25˚  2002    강원도      삼척시  37.885000
# 13                       설치각 : 25˚   990    강원도      삼척시  37.885000
# 14  설치각 : 25˚(지면경사 : 0˚) 입사각 : 23˚   999    강원도      삼척시  37.885000
# 15                       설치각 : 24˚   997    제주도      제주시  33.393992
# 16                       설치각 : 15˚   296  인천광역시       서구  37.456000
# 17                       설치각 : 20˚  1742  인천광역시       서구  37.456000
# 18                       설치각 : 18˚   302  인천광역시       서구  37.456000
# 19                       설치각 : 25˚    63  인천광역시       서구  37.456000
# 20                     설치각 : 8~45˚   200  인천광역시       서구  37.456000
# 21              설치각 : 25˚, 10˚~20˚   606  인천광역시       서구  37.456000
# 22                       설치각 : 23˚   907  인천광역시       서구  37.456000
# 23                       설치각 : 24˚   991    제주도     서귀포시  33.393992
# 24                       설치각 : 21˚   285   경상북도      안동시  36.575400
# 25                       설치각 : 25˚    98   경상북도      안동시  36.575400
# 26                       설치각 : 26˚   175    강원도      영월군  37.885000
# 27  설치각 : 30˚(지면경사 : 0˚) 입사각 : 25˚  1190    강원도      영월군  37.885000
# 28                       설치각 : 25˚   995    제주도  제주특별자치도  33.393992
# 29                       설치각 : 23˚   998  인천광역시      남동구  37.456000
# 30                       설치각 : 18˚   889    제주도      제주시  33.393992
# 31                       설치각 : 30˚   370   경상남도      하동군  35.238200
# 32                       설치각 : 30˚   250   경상남도      하동군  35.238200
# 33                       설치각 : 30˚    48   경상남도      하동군  35.238200
# 34                          지붕에 설치    93   경상남도      하동군  35.238200
# 35                       설치각 : 30˚   250   경상남도      하동군  35.238200
# 36                       설치각 : 32˚   998   경상남도      하동군  35.238200
# 37                       설치각 : 32˚  1901   경상남도      하동군  35.238200
# 38                       설치각 : 32˚   601   경상남도      하동군  35.238200
# 39             설치각 : 30˚ 입사각 : 23˚   998   경상남도      하동군  35.238200
# 40                       설치각 : 30˚   998   경상남도      하동군  35.238200
# 41                       설치각 : 22˚   998   경상남도      하동군  35.238200
# 42                       설치각 : 20˚  1000   경상남도      하동군  35.238200
# 43                       설치각 : 30˚   233    제주도      제주시  33.393992
# 44                       설치각 : 20˚   554   충청북도       충북  36.635700
#
#         lng_do
# 0   126.562665
# 1   126.562665
# 2   129.075236
# 3   129.075236
# 4   129.075236
# 5   129.075236
# 6   129.075236
# 7   129.075236
# 8   129.075236
# 9   127.009500
# 10  127.729700
# 11  127.729700
# 12  127.729700
# 13  127.729700
# 14  127.729700
# 15  126.562665
# 16  126.705200
# 17  126.705200
# 18  126.705200
# 19  126.705200
# 20  126.705200
# 21  126.705200
# 22  126.705200
# 23  126.562665
# 24  128.505800
# 25  128.505800
# 26  127.729700
# 27  127.729700
# 28  126.562665
# 29  126.705200
# 30  126.562665
# 31  128.692500
# 32  128.692500
# 33  128.692500
# 34  128.692500
# 35  128.692500
# 36  128.692500
# 37  128.692500
# 38  128.692500
# 39  128.692500
# 40  128.692500
# 41  128.692500
# 42  128.692500
# 43  126.562665
# 44  127.491500

# %% [markdown]
# #### 2) 지도 시각화

# %%
import folium

# %%
map = folium.Map(location = [35.7,128], zoom_start = 6.5)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2664a05652e28879b7c2a81fed4b0104 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2664a05652e28879b7c2a81fed4b0104&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2664a05652e28879b7c2a81fed4b0104 = L.map(
#                 &quot;map_2664a05652e28879b7c2a81fed4b0104&quot;,
#                 {
#                     center: [35.7, 128.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a8883792f49cd41301d83ea56ea6048 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2664a05652e28879b7c2a81fed4b0104);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location = [35.7,128], zoom_start = 6.5)

for i in range(len(df)):
#    print(i) i는 숫번만 나타냄
    
    name = df['발전소명'][i]
    cap = df['설비용량'][i]
    popup = f"{name}:{cap}kW"
    folium.CircleMarker(location = [df['lat_do'][i],df['lng_do'][i]],
                        radius=df['설비용량'][i]/100, popup=popup, ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0024dc882f7802b97feeb2a55981d9be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0024dc882f7802b97feeb2a55981d9be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0024dc882f7802b97feeb2a55981d9be = L.map(
#                 &quot;map_0024dc882f7802b97feeb2a55981d9be&quot;,
#                 {
#                     center: [35.7, 128.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_869a396998ef3f0d1fa1d940bff4c72e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0024dc882f7802b97feeb2a55981d9be);
#
#
#             var circle_marker_29bd872174a5cbe7c5e7f11cced8b580 = L.circleMarker(
#                 [0.0, 126.5626653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.96, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0024dc882f7802b97feeb2a55981d9be);
#
#
#         var popup_95aa52a1a2785876cb7322f7ccdd7c67 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be60c052f555ca3020c4d4e56a9431ed = $(`&lt;div id=&quot;html_be60c052f555ca3020c4d4e56a9431ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남제주소내:196kW&lt;/div&gt;`)[0];
#                 popup_95aa52a1a2785876cb7322f7ccdd7c67.setContent(html_be60c052f555ca3020c4d4e56a9431ed);
#
#
#
#         circle_marker_29bd872174a5cbe7c5e7f11cced8b580.bindPopup(popup_95aa52a1a2785876cb7322f7ccdd7c67)
#         ;
#
#
#
#
#             var circle_marker_5ed00b09ecbf30593d10b191f09ce899 = L.circleMarker(
#                 [33.3939924, 126.5626653],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.09, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0024dc882f7802b97feeb2a55981d9be);
#
#
#         var popup_ae9b96da1d815c90d68ee60347f263a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7cd497778a611b9470f3ad3821f715c = $(`&lt;div id=&quot;html_d7cd497778a611b9470f3ad3821f715c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;무릉리 (제주):809kW&lt;/div&gt;`)[0];
#                 popup_ae9b96da1d815c90d68ee60347f263a1.setContent(html_d7cd497778a611b9470f3ad3821f715c);
#
#
#
#         circle_marker_5ed00b09ecbf30593d10b191f09ce899.bindPopup(popup_ae9b96da1d815c90d68ee60347f263a1)
#         ;
#
#
#
#
#             var circle_marker_2a3e1913d4c5a15be9deb1eeaa64d4bb = L.circleMarker(
#                 [35.1799528, 129.0752365],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0024dc882f7802b97feeb2a55981d9be);
#
#
#         var popup_a64ce3e9841aacc240f393b4d3e2680c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_670277b96999e7003ccee5c9b2da63cc = $(`&lt;div id=&quot;html_670277b96999e7003ccee5c9b2da63cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산 수처리 건물:110kW&lt;/div&gt;`)[0];
#                 popup_a64ce3e9841aacc240f393b4d3e2680c.setContent(html_670277b96999e7003ccee5c9b2da63cc);
#
#
#
#         circle_marker_2a3e1913d4c5a15be9deb1eeaa64d4bb.bindPopup(popup_a64ce3e9841aacc240f393b4d3e2680c)
#         ;
#
#
#
#
#             var circle_marker_52fab1e3a5f0db9c78d01ada708b012f = L.circleMarker(
#                 [35.1799528, 129.0752365],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenod

# %% [markdown]
# ### 3.2 도/시별 설비용량 시각화

# %% [markdown]
# #### 1) 도/시별 그룹화

# %%
#df.groupby(['도/시','lat_do','lng_do']).sum()
df_Do=df.groupby(['도/시','lat_do','lng_do'],as_index=False).sum()
df_Do
# Out:
#      도/시     lat_do      lng_do  설비용량
# 0    강원도  37.885000  127.729700  8196
# 1    경기도  37.275200  127.009500   995
# 2   경상남도  35.238200  128.692500  8505
# 3   경상북도  36.575400  128.505800   383
# 4  부산광역시  35.179953  129.075236  3538
# 5  인천광역시  37.456000  126.705200  5114
# 6    제주도   0.000000  126.562665   196
# 7    제주도  33.393992  126.562665  4914
# 8   충청북도  36.635700  127.491500   554

# %%
map = folium.Map(location = [35.7,128], zoom_start = 6.5)

for i in range(len(df_Do)):
#    print(i) i는 숫번만 나타냄
    
    name = df_Do['도/시'][i]
    cap = df_Do['설비용량'][i]
    popup = f"{name}: {cap}kW"
    
    folium.CircleMarker(location = [df_Do['lat_do'][i],df_Do['lng_do'][i]],
                        radius=df['설비용량'][i]/300, popup=popup,
                        tooltip=popup ).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69aef85e29989a45278328b7f7addc45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69aef85e29989a45278328b7f7addc45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_69aef85e29989a45278328b7f7addc45 = L.map(
#                 &quot;map_69aef85e29989a45278328b7f7addc45&quot;,
#                 {
#                     center: [35.7, 128.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_585e224eabb33049547451ef474f7490 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_69aef85e29989a45278328b7f7addc45);
#
#
#             var circle_marker_5bfe7b6b35c86f9ab72d53783b9285e7 = L.circleMarker(
#                 [37.885, 127.7297],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.6533333333333333, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69aef85e29989a45278328b7f7addc45);
#
#
#         var popup_3ab05ae638058c0c3e01d31b2e3a8335 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97d676737369bf6726f93816083cbded = $(`&lt;div id=&quot;html_97d676737369bf6726f93816083cbded&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;강원도: 8196kW&lt;/div&gt;`)[0];
#                 popup_3ab05ae638058c0c3e01d31b2e3a8335.setContent(html_97d676737369bf6726f93816083cbded);
#
#
#
#         circle_marker_5bfe7b6b35c86f9ab72d53783b9285e7.bindPopup(popup_3ab05ae638058c0c3e01d31b2e3a8335)
#         ;
#
#
#
#
#             circle_marker_5bfe7b6b35c86f9ab72d53783b9285e7.bindTooltip(
#                 `&lt;div&gt;
#                      강원도: 8196kW
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_db2fadfbd66a0d11c3c7811575a05d11 = L.circleMarker(
#                 [37.2752, 127.0095],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.6966666666666668, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69aef85e29989a45278328b7f7addc45);
#
#
#         var popup_a1393703b971041b88dd03fd5775645a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68c78165e2bc4ead42f340d6f4e8923b = $(`&lt;div id=&quot;html_68c78165e2bc4ead42f340d6f4e8923b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경기도: 995kW&lt;/div&gt;`)[0];
#                 popup_a1393703b971041b88dd03fd5775645a.setContent(html_68c78165e2bc4ead42f340d6f4e8923b);
#
#
#
#         circle_marker_db2fadfbd66a0d11c3c7811575a05d11.bindPopup(popup_a1393703b971041b88dd03fd5775645a)
#         ;
#
#
#
#
#             circle_marker_db2fadfbd66a0d11c3c7811575a05d11.bindTooltip(
#                 `&lt;div&gt;
#                      경기도: 995kW
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_4df5fb5bfcaf260c2a26dcea80d5cf68 = L.circleMarker(
#                 [35.2382, 128.6925],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.36666666666666664, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69aef85e29989a45278328b7f7addc45);
#
#
#         var popup_a77380abc8050895efdacdf631ee3505 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6dcb27afa253a6f60b62042910a8a4f1 = $(`&lt;div id=&quot;html_6dcb27afa253a6f60b62042910a8a4f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경상남도: 8505kW&lt;/div&gt;`)[0];
#                 popup_a77380abc8050895efdacdf631ee3505.setContent(html_6dcb27afa253a6f60b62042910a8a4f1);
#
#
#
#         circle_marker_4df5fb5bfcaf260c2a26dcea8

# %% [markdown]
# #### 3.3 시/군/구별 설비용량 시각화

# %%
lat_si, lng_si = convert_lat_lng(df['시/군/구'])
df['lat_si'] = lat_si
df['lng_si'] = lng_si

# %%
df
# Out:
#               발전소명                                            발전소 주소지  \
# 0            남제주소내                        제주도 서귀포시 안덕면 화순해안로 106번길 55
# 1         무릉리 (제주)                      제주도 서귀포시 대정읍 무릉리 1193-3 외 3필지
# 2        부산 수처리 건물                         부산광역시 사하구 감천항로 7(감천동) 수처리실
# 3   부산발전본부 1,400kW                              부산광역시 사하구 감천항로 7(감천동)
# 4         부산복합 2단계                              부산광역시 사하구 감천항로 7(감천동)
# 5        부산복합 자재창고                              부산광역시 사하구 감천항로 7(감천동)
# 6             부산복합                                   부산광역시 사하구 감천항로 7
# 7             부산신항                                 부산광역시 강서구 성북동 1490
# 8       부산역 선상 주차장                              부산광역시 동구 초량3동 1187-1
# 9        이천D(백사면B)                              경기도 이천시 백사면 도립리 141-1
# 10         삼척 소내#4                                강원도 삼척시 원덕읍 삼척로 734
# 11            삼척사택                     강원도 삼척시 원덕읍 삼척로 581-7 삼척그린파워사택
# 12        삼척소내 # 3                                강원도 삼척시 원덕읍 삼척로 734
# 13         삼척소내 #2                                강원도 삼척시 원덕읍 삼척로 734
# 14          삼척소내#1                                강원도 삼척시 원덕읍 삼척로 734
# 15        송당리 (제주)                               제주도 제주시 구좌읍 송당리 2455
# 16    신인천 1,2단계주차장                              인천광역시 서구 장도로 57 (청라동)
# 17     신인천 법사면 전망대                              인천광역시 서구 장도로 57 (청라동)
# 18        신인천 북측부지                              인천광역시 서구 장도로 57 (청라동)
# 19        신인천 본관옥상                              인천광역시 서구 장도로 57 (청라동)
# 20          신인천 소내                              인천광역시 서구 장도로 57 (청라동)
# 21         신인천 주차장                              인천광역시 서구 장도로 57 (청라동)
# 22       신인천 해수취수구                              인천광역시 서구 장도로 57 (청라동)
# 23        신풍리 (제주)                              제주도 서귀포시 성산읍 신풍리 1522
# 24      안동발전본부 2단계                            경상북도 안동시 풍산읍 산업단지 1길 38
# 25          안동발전본부                            경상북도 안동시 풍산읍 산업단지 1길 38
# 26            영월복합                                강원도 영월군 영월읍 중앙로 411
# 27          영월철도부지                    강원도 영월군 영월읍 중앙로 411 정양리 일원(585)
# 28         위미2리 제2                      제주도 제주특별자치도 서귀포시 남원읍 위미리 3696
# 29         인천수산정수장                                인천광역시 남동구 수산동 294-4
# 30          제주 용수리                            제주도 제주시 한경면 용수리 457 외 2
# 31         하동공설운동장                            경상남도 하동군 적량면 고절리 1209-1
# 32          하동군보건소                             경상남도 하동군 하동읍 읍내리 149-1
# 33           하동변전소                               경상남도 하동군 적량면 동산리 867
# 34           하동정수장                               경상남도 하동군 하동읍 두곡리 543
# 35         하동하수처리장                               경상남도 하동군 하동읍 신기리 2-2
# 36         하동화력 #1                               경상남도 하동군 금성면 가덕리 310
# 37         하동화력 #2                               경상남도 하동군 금성면 가덕리 310
# 38         하동화력 #3                               경상남도 하동군 금성면 가덕리 310
# 39         하동화력 #4  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 40         하동화력 #5  경상남도 하동군 금남면 덕오길 173-176 금남면 대송리 482, 491, 492...
# 41         하동화력 #6                          경상남도 하동군 금성면 가덕리 1321,309
# 42      화촌주민참여형솔라팜                      경상남도 하동군 양보면 지례리 183-5 외 10필지
# 43           행원소수력                              제주도 제주시 구좌읍 행원리 571-2
# 44             감우리                         충청북도 충북 음성군 음성읍 감우리 23, 24
#
#                                                  설치용량  \
# 0              196kW 모듈 :250W x 784 인버터 : 100kW x 2EA
# 1         809.2kW 모듈 : 425W  x 1904 인버터 : 100kW x 8EA
# 2           110.5kW 모듈 : 340Wⅹ325 인버터 : 100kW, 10.5kW
# 3         1,400.475kW 모듈 : 355Wⅹ3,945 인버터 : 500kWⅹ3EA
# 4        501.84kW 모듈 : 340W x 1,476 인버터 : 600kW x 1EA
# 5               187kW 모듈 : 300Wⅹ624 인버터 : 100kW x 2EA
# 6   390kW 모듈 :170W x 1,155 인버터 : 100kW x 3EA, 50kW...
# 7   115kW 모듈 :144Wp x 272, 100Wp x 384, 215Wp x 17...
# 8           834kW 모듈 : 400W x 2086, 인버터 : 500kW x 2EA
# 9           995kW 모듈 : 440W x 2272, 인버터 : 500kW X 2EA
# 10       2,599.2kW 모듈 : 380Wⅹ6,840 인버터 : 1250kW x 2EA
# 11  241kW 모듈 : 250ⅹ964 인버터 : 36kWⅹ2, 41kWⅹ1, 46kWⅹ...
# 12  2,002.32kW 모듈 : 360Wⅹ5,562 인버터 : 500kWⅹ1EA, 15...
# 13           990.45kW모듈 : 355Wⅹ2,790 인버터 : 500kWⅹ2EA
# 14              999kW 모듈 : 360Wⅹ2,775 인버터 : 500kWⅹ2EA
# 15      996.93kW 모듈 : 330W ⅹ 3,021 인버터 : 105kW ⅹ 10EA
# 16          296.1kW 모듈 : 450W x 658 인버터 : 100kW x 3EA
# 17         1,742kW 모듈 :475W x 3,668 인버터 : 250kW x 7EA
# 18          302.4kW 모듈 : 450W x 672 인버터 : 100kW x 3EA
# 19           63.0kW 모듈 : 450W x 140 인버터 : 100kW x 1EA
# 20            200kW 모듈 : 250W x 800 인버터 : 210kW x 1EA
# 21  605.55kW 모듈 : 390W X1,545 인버터 : 100kW x 6EA, 3...
# 22        907.2kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 23       990.72kW 모듈 : 360W x 2,520 인버터 : 250kW x 4EA
# 24          284.7kW 모듈 : 365W x 780 인버터 : 100kW x 3EA
# 25                  97.92kW모듈 : 340Wⅹ288 인버터 : 99.4kW
# 26  76kW 모듈 :175W x 432 인버터 : 30.21kVA x 2EA, 20kV...
# 27          1,190.7kW 모듈 : 350Wⅹ3,402 인버터 : 600kWⅹ2EA
# 28       994.84kW 모듈 : 340W x 2,926 인버터 : 500kW x 2EA
# 29           998kW 모듈 :230W x 4,284 인버터 : 250kW x 4EA
# 30       888.93kW 모듈 : 415W x 2,142 인버터 : 105kW x 9EA
# 31  369.85kW 모듈 :250W x 980, 144W x 867  인버터 : 250...
# 32               40kW 모듈 :250W x 220 인버터 : 40kW x 1EA
# 33             48.3kW 모듈 :230W x 210 인버터 : 50kW x 1EA
# 34           93.02kW 모듈 :144W x 646 인버터 : 100kW x 1EA
# 35               55kW 모듈 :250W x 160 인버터 : 55kW x 1EA
# 36         998.4kW 모듈 :160W x 6,256 인버터 : 250kW x 5EA
# 37  1900.8kW 모듈 :100/144/160/230W x 11,196 인버터 : 1...
# 38         600.6kW 모듈 :220W x 2,730 인버터 : 100kW x 7EA
# 39            997.56kW모듈 : 340Wⅹ2,934 인버터 : 500kWⅹ2EA
# 40        997.56W 모듈 : 340W x 2,934 인버터 : 500kW x 2EA
# 41       998.325kW 모듈 : 435W x 2295 인버터 : 500kW x 2EA
# 42        999.6kW 모듈 : 420W x 2380 인버터 : 100kW x 10EA
# 43                 6kW 모듈 :233W x 25 인버터 : 10kW x 1EA
# 44        554.4kW 모듈 : 440W x 1,260 인버터 : 630kW x 1EA
#
#                                설치각  설비용량    도/시    시/군/구     lat_do  \
# 0                        설치각 : 30˚   196    제주도     서귀포시   0.000000
# 1                        설치각 : 20˚   809    제주도     서귀포시  33.393992
# 2              설치각 : 25˚ 입사각 : 23˚   110  부산광역시      사하구  35.179953
# 3                        설치각 : 25˚  1400  부산광역시      사하구  35.179953
# 4                        설치각 : 25˚   502  부산광역시      사하구  35.179953
# 5                        설치각 : 27˚   187  부산광역시      사하구  35.179953
# 6                    설치각 : 21˚~45˚   390  부산광역시      사하구  35.179953
# 7                        설치각 : 17˚   115  부산광역시      강서구  35.179953
# 8                     설치각 : 3˚~23˚   834  부산광역시       동구  35.179953
# 9                        설치각 : 25˚   995    경기도      이천시  37.275200
# 10                       설치각 : 25˚  2599    강원도      삼척시  37.885000
# 11                       사택 지붕에 설치   241    강원도      삼척시  37.885000
# 12                       설치각 : 25˚  2002    강원도      삼척시  37.885000
# 13                       설치각 : 25˚   990    강원도      삼척시  37.885000
# 14  설치각 : 25˚(지면경사 : 0˚) 입사각 : 23˚   999    강원도      삼척시  37.885000
# 15                       설치각 : 24˚   997    제주도      제주시  33.393992
# 16                       설치각 : 15˚   296  인천광역시       서구  37.456000
# 17                       설치각 : 20˚  1742  인천광역시       서구  37.456000
# 18                       설치각 : 18˚   302  인천광역시       서구  37.456000
# 19                       설치각 : 25˚    63  인천광역시       서구  37.456000
# 20                     설치각 : 8~45˚   200  인천광역시       서구  37.456000
# 21              설치각 : 25˚, 10˚~20˚   606  인천광역시       서구  37.456000
# 22                       설치각 : 23˚   907  인천광역시       서구  37.456000
# 23                       설치각 : 24˚   991    제주도     서귀포시  33.393992
# 24                       설치각 : 21˚   285   경상북도      안동시  36.575400
# 25                       설치각 : 25˚    98   경상북도      안동시  36.575400
# 26                       설치각 : 26˚   175    강원도      영월군  37.885000
# 27  설치각 : 30˚(지면경사 : 0˚) 입사각 : 25˚  1190    강원도      영월군  37.885000
# 28                       설치각 : 25˚   995    제주도  제주특별자치도  33.393992
# 29                       설치각 : 23˚   998  인천광역시      남동구  37.456000
# 30                       설치각 : 18˚   889    제주도      제주시  33.393992
# 31                       설치각 : 30˚   370   경상남도      하동군  35.238200
# 32                       설치각 : 30˚   250   경상남도      하동군  35.238200
# 33                       설치각 : 30˚    48   경상남도      하동군  35.238200
# 34                          지붕에 설치    93   경상남도      하동군  35.238200
# 35                       설치각 : 30˚   250   경상남도      하동군  35.238200
# 36                       설치각 : 32˚   998   경상남도      하동군  35.238200
# 37                       설치각 : 32˚  1901   경상남도      하동군  35.238200
# 38                       설치각 : 32˚   601   경상남도      하동군  35.238200
# 39             설치각 : 30˚ 입사각 : 23˚   998   경상남도      하동군  35.238200
# 40                       설치각 : 30˚   998   경상남도      하동군  35.238200
# 41                       설치각 : 22˚   998   경상남도      하동군  35.238200
# 42                       설치각 : 20˚  1000   경상남도      하동군  35.238200
# 43                       설치각 : 30˚   233    제주도      제주시  33.393992
# 44                       설치각 : 20˚   554   충청북도       충북  36.635700
#
#         lng_do     lat_si      lng_si
# 0   126.562665  33.257297  126.515299
# 1   126.562665  33.257297  126.515299
# 2   129.075236  35.104100  128.975100
# 3   129.075236  35.104100  128.975100
# 4   129.075236  35.104100  128.975100
# 5   129.075236  35.104100  128.975100
# 6   129.075236  35.104100  128.975100
# 7   129.075236  37.550900  126.849700
# 8   129.075236  35.886500  128.635500
# 9   127.009500  37.280882  127.442913
# 10  127.729700  37.449874  129.165297
# 11  127.729700  37.449874  129.165297
# 12  127.729700  37.449874  129.165297
# 13  127.729700  37.449874  129.165297
# 14  127.729700  37.449874  129.165297
# 15  126.562665  33.493057  126.513059
# 16  126.705200  37.545000  126.676000
# 17  126.705200  37.545000  126.676000
# 18  126.705200  37.545000  126.676000
# 19  126.705200  37.545000  126.676000
# 20  126.705200  37.545000  126.676000
# 21  126.705200  37.545000  126.676000
# 22  126.705200  37.545000  126.676000
# 23  126.562665  33.257297  126.515299
# 24  128.505800  36.563489  128.726080
# 25  128.505800  36.563489  128.726080
# 26  127.729700  37.183498  128.461981
# 27  127.729700  37.183498  128.461981
# 28  126.562665  33.488774  126.498708
# 29  126.705200  37.446902  126.731513
# 30  126.562665  33.493057  126.513059
# 31  128.692500  35.067279  127.751741
# 32  128.692500  35.067279  127.751741
# 33  128.692500  35.067279  127.751741
# 34  128.692500  35.067279  127.751741
# 35  128.692500  35.067279  127.751741
# 36  128.692500  35.067279  127.751741
# 37  128.692500  35.067279  127.751741
# 38  128.692500  35.067279  127.751741
# 39  128.692500  35.067279  127.751741
# 40  128.692500  35.067279  127.751741
# 41  128.692500  35.067279  127.751741
# 42  128.692500  35.067279  127.751741
# 43  126.562665  33.493057  126.513059
# 44  127.491500  36.635700  127.491500

# %% [markdown]
# #### 2) 시/군/구별 그룹화

# %%
df_Si=df[['시/군/구','설비용량','lat_si','lng_si']].groupby(['시/군/구','설비용량','lat_si','lng_si']).as_index=False.sum()
df_Si
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 df_Si=df[['시/군/구','설비용량','lat_si','lng_si']].groupby(['시/군/구','설비용량','lat_si','lng_si']).as_index=False.sum()
#       2 df_Si
#
# AttributeError: 'bool' object has no attribute 'sum'
